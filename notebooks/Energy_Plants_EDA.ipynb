# %% [markdown]
# # Perform EDA on Plant Data

# %%
try:
    from google.colab import drive

    drive.mount('./drive/')

    # %cd drive/My \ Drive/Data606_Energy

except:
    print("No Colab Environment")
# Out:
# Drive already mounted at ./drive/; to attempt to forcibly remount, call drive.mount("./drive/", force_remount=True).
# [Errno 2] No such file or directory: 'drive/My Drive/Data606_Energy'
# /content

# %%
# !ls drive/MyDrive/Data606_Energy
# Out:
# drive/MyDrive/Data606_Energy

# %%
import sys
import pandas as pd
import glob
from tqdm.autonotebook import tqdm
sys.path.append("helpers/")

from energygrid import EGRID

from helper_functions import write_csv, combine_like_files
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   after removing the cwd from sys.path.

# %%
path = "data/powerplant/plants_by_state/Net_Generation/All/*_net_generation_.json"
df = combine_like_files(path,pd.read_json)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2227104 entries, 0 to 2227103
# Data columns (total 16 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   series_id    object
#  1   name         object
#  2   units        object
#  3   f            object
#  4   description  object
#  5   copyright    object
#  6   source       object
#  7   iso3166      object
#  8   lat          float64
#  9   lon          float64
#  10  latlon       object
#  11  geography    object
#  12  start        int64
#  13  end          int64
#  14  updated      object
#  15  data         object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 271.9+ MB

# %%
df
# Out:
#                           series_id  ...               data
# 0        ELEC.PLANT.GEN.2-ALL-ALL.M  ...  [201912, -22.346]
# 1        ELEC.PLANT.GEN.2-ALL-ALL.M  ...  [201911, -21.282]
# 2        ELEC.PLANT.GEN.2-ALL-ALL.M  ...   [201910, -18.28]
# 3        ELEC.PLANT.GEN.2-ALL-ALL.M  ...   [201909, -18.33]
# 4        ELEC.PLANT.GEN.2-ALL-ALL.M  ...  [201908, -22.872]
# ...                             ...  ...                ...
# 2227099  ELEC.PLANT.GEN.2-ALL-ALL.M  ...     [200105, 8961]
# 2227100  ELEC.PLANT.GEN.2-ALL-ALL.M  ...    [200104, 27284]
# 2227101  ELEC.PLANT.GEN.2-ALL-ALL.M  ...    [200103, 37749]
# 2227102  ELEC.PLANT.GEN.2-ALL-ALL.M  ...    [200102, 30207]
# 2227103  ELEC.PLANT.GEN.2-ALL-ALL.M  ...    [200101, 18918]
#
# [2227104 rows x 16 columns]
