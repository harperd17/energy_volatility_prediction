# %% [markdown]
# # Goal - Understand USA grid and what resources are located where
# * What is the pricing per State and what energy resource contribute to that
# * Do State Taxes or National Taxes influence energy prices

# %% [markdown]
# # To Do
# * Write dictionary describing the fuel_types

# %% [markdown]
# [EIA Vocab](https://www.eia.gov/tools/glossary/index.php?id=G)

# %% [markdown]
# # Getting Powerplant Data
#
# # Probably can query this instead of downloading each link below
# # https://www.eia.gov/opendata/qb.php?category=1017
#
# * [BioMass](https://atlas.eia.gov/datasets/biomass-2/explore?location=44.619557%2C61.504001%2C3.67&showTable=true) - Organic nonfossil material of biological origin constituting a renewable energy source.
# * [Petroleum](https://atlas.eia.gov/datasets/petroleum-2/explore?location=44.619557%2C61.504001%2C3.67)
# * [Other](https://atlas.eia.gov/datasets/other/explore?location=44.619557%2C61.504001%2C3.67)
# * [Battery Storage](https://atlas.eia.gov/datasets/battery-storage/explore?location=44.619557%2C61.504001%2C3.67)
# * [Hydro Electric](https://atlas.eia.gov/datasets/hydroelectric-2/explore?location=44.619557%2C61.504001%2C3.67)
# * [Nuclear](https://atlas.eia.gov/datasets/nuclear/explore?location=44.619557%2C61.504001%2C3.67)
# * [Solar](https://atlas.eia.gov/datasets/solar-2/explore?location=44.619557%2C61.504001%2C3.67)
# * [Wind](https://atlas.eia.gov/datasets/wind-2/explore?location=44.619557%2C61.504001%2C3.67)
# * [Coal](https://atlas.eia.gov/datasets/coal-1/explore?location=44.619557%2C61.504001%2C3.67)
# * [Natural Gas](https://atlas.eia.gov/datasets/natural-gas-1/explore?location=44.619557%2C61.504001%2C3.67)
# * [Geothermal](https://atlas.eia.gov/datasets/geothermal-1/explore?location=44.619557%2C61.504001%2C3.67)
# * [Pumped Storage](https://atlas.eia.gov/datasets/pumped-storage/explore?location=44.619557%2C61.504001%2C3.67)
#
# * [Map](https://atlas.eia.gov/maps/power-plants-1/about)

# %% [markdown]
# * **Generation** is a measure of electricity produced over time. Most electric power plants use some of the electricity they produce to operate the power plant.
# * **Capacity** is the maximum level of electric power (electricity) that a power plant can supply at a specific point in time under certain conditions.
# * **Sales** are the amount of electricity sold to customers over a period of time, and they account for most of U.S. electricity consumption.

# %%
from google.colab import drive

drive.mount('./drive/')

# %cd drive/Shareddrives/Data606_Energy
# Out:
# Mounted at ./drive/
# /content/drive/Shareddrives/Data606_Energy

# %%
import sys
import pandas as pd
import numpy as np
import glob
from tqdm.autonotebook import tqdm
import plotly.express as px
sys.path.append("helpers/")

from energygrid import EGRID

from helper_functions import write_csv,combine_like_files
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   """

# %%
energy_grid = EGRID()
energy_grid.get_states()
energy_grid.get_plant_fuel_types()

# %%
#Net_Generation/plant_by_state/low_level_combine_net_generation_primsource.feather
df_pp = pd.read_feather("data/powerplant/plants_by_state/Net_Generation/LowLevel_FuelType/combine/low_level_combine_net_generation_primsource.feather")

# %%
df_pp
# Out:
#                               series_id  ... description
# 0          ELEC.PLANT.GEN.589-DFO-ALL.M  ...        None
# 1          ELEC.PLANT.GEN.589-DFO-ALL.M  ...        None
# 2          ELEC.PLANT.GEN.589-DFO-ALL.M  ...        None
# 3          ELEC.PLANT.GEN.589-DFO-ALL.M  ...        None
# 4          ELEC.PLANT.GEN.589-DFO-ALL.M  ...        None
# ...                                 ...  ...         ...
# 1864419  ELEC.PLANT.GEN.52152-MSB-ALL.M  ...        None
# 1864420  ELEC.PLANT.GEN.52152-MSB-ALL.M  ...        None
# 1864421  ELEC.PLANT.GEN.52152-MSB-ALL.M  ...        None
# 1864422  ELEC.PLANT.GEN.52152-MSB-ALL.M  ...        None
# 1864423  ELEC.PLANT.GEN.52152-MSB-ALL.M  ...        None
#
# [1864424 rows x 16 columns]

# %%
#https://plotly.com/python/mapbox-layers/

fig = px.scatter_mapbox(df_pp, lat="lat", lon="lon", hover_name="state", hover_data=["state", "plant_code","fuel_type"], zoom=3, height=300)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()

# %%
keep_cols = [col for col in df_pp.columns if (col.startswith("R") and col.endswith("MWh")) or col == "Year" or col == "State"]

px.df_pp[keep_cols]
# Out:
#        Year State  variable  value
# 0      2008    AK  R_AB_MWh  0.000
# 1      2008    AL  R_AB_MWh  0.000
# 2      2008    AR  R_AB_MWh  0.000
# 3      2008    AZ  R_AB_MWh  0.000
# 4      2008    CA  R_AB_MWh  0.001
# ...     ...   ...       ...    ...
# 24695  2020    VT  R_WO_MWh  0.000
# 24696  2020    WA  R_WO_MWh  0.000
# 24697  2020    WI  R_WO_MWh  0.000
# 24698  2020    WV  R_WO_MWh  0.000
# 24699  2020    WY  R_WO_MWh  0.000
#
# [24700 rows x 4 columns]

# %%
def calc_correlation(df,method="pearson",threshold=1):

    #Create Correlation Matrix
    corr = abs(df.corr(method=method).dropna(axis=1,how="all"))    

    #Specifies what columns to keep based on threshold and inverse threshold
    upper_tri = corr.where(np.triu(np.ones(corr.shape),k=1).astype(np.bool))
    to_drop = [column for column in upper_tri.columns if any(upper_tri[column] >= threshold)]

    #Drops specified columns
    corr = corr.drop(columns=to_drop)#columns

    return corr

# %%
energy_grid.plant_fuel_types
# Out:
# {'Disolate Fue Oil': 'DFO',
#  'Natural Gas': 'NG',
#  'Nuclear': 'NUC',
#  'Other': 'OTH',
#  'Solar': 'SUN',
#  'Wind': 'WND',
#  'agricultural by-products': 'AB',
#  'batteries or other use of electricity as an energy source': 'MWH',
#  'biogenic municipal solid waste': 'MSB',
#  'bituminous coal': 'BIT',
#  'black liquour': 'BLQ',
#  'blast furnace gas': 'BFG',
#  'coal-derived synthetic gas': 'SGC',
#  'gaseous propane': 'PG',
#  'geothermal': 'GEO',
#  'hydroelectric': 'WAT',
#  'jet fuel': 'JF',
#  'kerosene': 'KER',
#  'landfill gas': 'LFG',
#  'lignite coal': 'LIG',
#  'municipal solid waste': 'MSW',
#  'non-biogenic municipal solid waste': 'MSN',
#  'other biomass gas': 'OBG',
#  'other biomass solids': 'OBS',
#  'other gas': 'OG',
#  'petroleum coke': 'PC',
#  'purchased steam': 'PUR',
#  'refined coal': 'RC',
#  'residual fuel oil': 'RFO',
#  'sludge waste': 'SLW',
#  'subbituminous coal': 'SUB',
#  'synthetic coal': 'SC',
#  'tire-derived fuels': 'TDF',
#  'waste heat': 'WH',
#  'waste/other coal': 'WC',
#  'waste/other oil': 'WO',
#  'wood/wood waste solids': 'WDS'}

# %%
keep_cols = set()

mwh_cols = [col for col in df_pp.columns if col.endswith("MWh")]

for col in df_pp[mwh_cols].columns:

    for row in df_pp[mwh_cols].columns:

        if col == row:

            continue

        else:

            corr_score = abs(df_pp[col].corr(df_pp[row]))

            if  corr_score >= 0.30:

                keep_cols.add(col)

# %%
import plotly.figure_factory as ff


corr = round(df_pp[keep_cols].corr(),2)
mask = np.triu(np.ones_like(corr, dtype=bool))


cols = [col.lstrip("R_").rstrip("_MWh") for col in df_pp[keep_cols].columns]

inv_map = {v: k for k, v in energy_grid.plant_fuel_types.items()}

hover_text = [col if col not in inv_map.keys() else inv_map[col] for col in cols]

fig = ff.create_annotated_heatmap(corr.mask(mask).to_numpy(),
                                  x=cols,
                                  y=cols,
                                  colorscale="delta",
                                  )

fig.update_layout(title_text="2008 - 2021 Correlation for MWh Columns (containing) at least 1 >= 0.30 linear correlation")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b17d4e3e-636e-42e6-97be-791c260590d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b17d4e3e-636e-42e6-97be-791c260590d3")) {
#                     Plotly.newPlot(
#                         'b17d4e3e-636e-42e6-97be-791c260590d3',
#                         [{"colorscale": [[0.0, "rgb(16, 31, 63)"], [0.09090909090909091, "rgb(38, 62, 144)"], [0.18181818181818182, "rgb(30, 110, 161)"], [0.2727272727272727, "rgb(60, 154, 171)"], [0.36363636363636365, "rgb(140, 193, 186)"], [0.45454545454545453, "rgb(217, 229, 218)"], [0.5454545454545454, "rgb(239, 226, 156)"], [0.6363636363636364, "rgb(195, 182, 59)"], [0.7272727272727273, "rgb(115, 152, 5)"], [0.8181818181818182, "rgb(34, 120, 36)"], [0.9090909090909091, "rgb(18, 78, 43)"], [1.0, "rgb(23, 35, 18)"]], "reversescale": false, "showscale": false, "type": "heatmap", "x": ["FO", "SUB", "SL", "DFO", "BFG", "MSN", "TDF", "OG", "NG", "GEO", "KER", "PUR", "BLQ", "WO", "PC", "MWH", "SUN", "WH", "AB", "WAT", "SGC", "WDS", "MSB", "OTH", "WC", "LFG"], "y": ["FO", "SUB", "SL", "DFO", "BFG", "MSN", "TDF", "OG", "NG", "GEO", "KER", "PUR", "BLQ", "WO", "PC", "MWH", "SUN", "WH", "AB", "WAT", "SGC", "WDS", "MSB", "OTH", "WC", "LFG"], "z": [[null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], [-0.08, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], [0.01, -0.08, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], [0.82, -0.11, -0.03, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], [-0.03, 0.03, -0.03, -0.04, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], [0.34, -0.23, 0.15, 0.27, -0.06, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], [0.02, -0.1, 0.81, -0.02, 0.01, 0.21, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], [0.04, -0.07, -0.04, 0.05, 0.02, -0.08, -0.05, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], [-0.15, -0.41, 0.04, -0.1, -0.07, 0.26, 0.01, 0.23, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], [0.15, -0.14, -0.03, 0.1, -0.05, -0.01, -0.04, 0.07, 0.22, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], [0.1, -0.11, -0.01, 0.07, -0.03, 0.06, -0.0, 0.31, 0.1, -0.02, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], [-0.01, -0.05, 0.6, -0.04, -0.03, 0.16, 0.86, 0.05, 0.01, -0.04, -0.02, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null], [-0.03, -0.13, 0.76, -0.08, -0.05, 0.1, 0.82, -0.05, 0.07, -0.08, -0.05, 0.73, null, null, null, null, null, null, null, null, null, null, null, null, null, null], [0.27, -0.05, -0.01, 0.67, -0.02, 0.07, -0.01, -0.01, -0.07, 0.02, 0.02, -0.02, -0.04, null, null, null, null, null, null, null, null, null, null, null, null, null], [-0.04, 0.06, -0.04, -0.07, 0.04, -0.09, -0.03, 0.28, 0.04, -0.07, -0.04, 0.13, 0.04, -0.03, null, null, null, null, null, null, null, null, null, null, null, null], [-0.16, 0.03, -0.05, -0.29, 0.01, -0.08, -0.1, -0.01, 0.03, -0.03, 0.06, -0.11, -0.05, -0.4, 0.01, null, null, null, null, null, null, null, null, null, null, null], [0.03, -0.16, -0.05, 0.0, -0.06, 0.02, -0.05, 0.01, 0.19, 0.49, -0.0, -0.05, 0.03, -0.01, -0.09, 0.05, null, null, null, null, null, null, null, null, null, null], [-0.05, 0.08, -0.04, -0.07, 0.09, -0.08, -0.05, 0.01, -0.01, 0.08, -0.05, -0.03, 0.07, -0.04, 0.38, 0.02, 0.25, null, null, null, null, null, null, null, null, null], [0.41, -0.05, -0.03, 0.34, -0.04, 0.18, -0.02, 0.13, 0.06, 0.19, -0.01, 0.04, -0.01, 0.12, 0.22, -0.24, 0.09, 0.14, null, null, n ...
#                         {"annotations": [{"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "nan", "x": "FO", "xref": "x", "y": "FO", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "nan", "x": "SUB", "xref": "x", "y": "FO", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "nan", "x": "SL", "xref": "x", "y": "FO", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "nan", "x": "DFO", "xref": "x", "y": "FO", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "nan", "x": "BFG", "xref": "x", "y": "FO", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "nan", "x": "MSN", "xref": "x", "y": "FO", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "nan", "x": "TDF", "xref": "x", "y": "FO", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "nan", "x": "OG", "xref": "x", "y": "FO", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "nan", "x": "NG", "xref": "x", "y": "FO", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "nan", "x": "GEO", "xref": "x", "y": "FO", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "nan", "x": "KER", "xref": "x", "y": "FO", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "nan", "x": "PUR", "xref": "x", "y": "FO", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "nan", "x": "BLQ", "xref": "x", "y": "FO", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "nan", "x": "WO", "xref": "x", "y": "FO", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "nan", "x": "PC", "xref": "x", "y": "FO", "yref": "y"}, {"font": {"color": "#FFFFFF"}, "showarrow": false, "text": "nan", "x"

# %%
df_pp.columns
# Out:
# Index(['state', 'year', 'Agg_total_plant_MWh', 'Agg_total_plant_count',
#        'R_AB_MWh', 'R_AB_count', 'R_BFG_MWh', 'R_BFG_count', 'R_BIT_MWh',
#        'R_BIT_count', 'R_BLQ_MWh', 'R_BLQ_count', 'R_DFO_MWh', 'R_DFO_count',
#        'R_GEO_MWh', 'R_GEO_count', 'R_JF_MWh', 'R_JF_count', 'R_KER_MWh',
#        'R_KER_count', 'R_LFG_MWh', 'R_LFG_count', 'R_LIG_MWh', 'R_LIG_count',
#        'R_MSB_MWh', 'R_MSB_count', 'R_MSN_MWh', 'R_MSN_count', 'R_MSW_MWh',
#        'R_MSW_count', 'R_MWH_MWh', 'R_MWH_count', 'R_NG_MWh', 'R_NG_count',
#        'R_NUC_MWh', 'R_NUC_count', 'R_OBG_MWh', 'R_OBG_count', 'R_OBS_MWh',
#        'R_OBS_count', 'R_OG_MWh', 'R_OG_count', 'R_OTH_MWh', 'R_OTH_count',
#        'R_PC_MWh', 'R_PC_count', 'R_PG_MWh', 'R_PG_count', 'R_PUR_MWh',
#        'R_PUR_count', 'R_RC_MWh', 'R_RC_count', 'R_RFO_MWh', 'R_RFO_count',
#        'R_SC_MWh', 'R_SC_count', 'R_SGC_MWh', 'R_SGC_count', 'R_SLW_MWh',
#        'R_SLW_count', 'R_SUB_MWh', 'R_SUB_count', 'R_SUN_MWh', 'R_SUN_count',
#        'R_TDF_MWh', 'R_TDF_count', 'R_WAT_MWh', 'R_WAT_count', 'R_WC_MWh',
#        'R_WC_count', 'R_WDS_MWh', 'R_WDS_count', 'R_WH_MWh', 'R_WH_count',
#        'R_WND_MWh', 'R_WND_count', 'R_WO_MWh', 'R_WO_count'],
#       dtype='object')

# %%
px.line(df_pp.sort_values("year",ascending=True),x="year",y="Agg_total_plant_count",color="state",title="Aggregate Plant Count by State")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9e8e5081-025a-464c-bfbc-d171a3988745" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9e8e5081-025a-464c-bfbc-d171a3988745")) {
#                     Plotly.newPlot(
#                         '9e8e5081-025a-464c-bfbc-d171a3988745',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "state=AK<br>year=%{x}<br>Agg_total_plant_count=%{y}", "legendgroup": "state=AK", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "state=AK", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [1549, 1804, 1752, 1800, 1848, 1925, 1977, 2093, 2117, 2164, 2146, 2148, 252, 147], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "state=ME<br>year=%{x}<br>Agg_total_plant_count=%{y}", "legendgroup": "state=ME", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "state=ME", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [1420, 1488, 1522, 1541, 1622, 1644, 1680, 1717, 1724, 1772, 1802, 1744, 509, 291], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "state=SC<br>year=%{x}<br>Agg_total_plant_count=%{y}", "legendgroup": "state=SC", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "state=SC", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [1602, 1565, 1632, 1716, 1775, 1836, 1867, 1857, 1896, 1959, 2215, 2520, 1035, 623], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "state=TN<br>year=%{x}<br>Agg_total_plant_count=%{y}", "legendgroup": "state=TN", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "state=TN", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [1044, 1033, 1012, 1042, 1082, 1152, 1199, 1221, 1239, 1254, 1275, 1319, 683, 389], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "state=OH<br>year=%{x}<br>Agg_total_plant_count=%{y}", "legendgroup": "state=OH", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "state=OH", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [1872, 1834, 1815, 1950, 2120, 2291, 2457, 2487, 2596, 2706, 2795, 2855, 989, 544], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "state=NV<br>year=%{x}<br>Agg_total_plant_count=%{y}", "legendgroup": "state=NV", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "lines", "name": "state=NV", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [587, 602, 643, 660, 731, 781, 849, 888, 946, 1027, 1080, 1151, 586, 343], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "state=WV<br>year=%{x}<br>Agg_total_plant_count=%{y}", "legendgroup": "state=WV", "line": {"color": "#FF6692", "dash": "solid"}, "mode": "lines", "name": "state=WV", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [524, 504, 516, 545, 589, 588, 583, 589, 637, 660, 655, 648, 418, 239], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "state=AZ<br>year=%{x}<br>Agg_total_plant_count=%{y}", "legendgroup": "state=AZ", "line": {"color": "#B6E880", "dash": "solid"}, "mode": "lines", "name": "state=AZ", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [862, 850, 912, 1087, 1154, 1423, 1513, 1555, 1624, 1768, 1872, 1909, 877, 512], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "st ...

# %%
(
px.line(df_pp.query('state != "CA" & state != "TX" & state != "NC"')
.sort_values("year",ascending=True)
,x="year",y="Agg_total_plant_count"
,color="state",title="Aggregate Plant Count by State")

)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0cc8ad3f-1c5d-4464-9bd0-a47023ed9aab" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0cc8ad3f-1c5d-4464-9bd0-a47023ed9aab")) {
#                     Plotly.newPlot(
#                         '0cc8ad3f-1c5d-4464-9bd0-a47023ed9aab',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "state=AK<br>year=%{x}<br>Agg_total_plant_count=%{y}", "legendgroup": "state=AK", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "state=AK", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [1549, 1804, 1752, 1800, 1848, 1925, 1977, 2093, 2117, 2164, 2146, 2148, 252, 147], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "state=NY<br>year=%{x}<br>Agg_total_plant_count=%{y}", "legendgroup": "state=NY", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "state=NY", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [4835, 4910, 4974, 5032, 5223, 5469, 5525, 5712, 6087, 6271, 6925, 7794, 1343, 762], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "state=NV<br>year=%{x}<br>Agg_total_plant_count=%{y}", "legendgroup": "state=NV", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "state=NV", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [587, 602, 643, 660, 731, 781, 849, 888, 946, 1027, 1080, 1151, 586, 343], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "state=NM<br>year=%{x}<br>Agg_total_plant_count=%{y}", "legendgroup": "state=NM", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "state=NM", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [467, 504, 539, 708, 756, 835, 968, 1033, 1185, 1261, 1369, 1478, 527, 284], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "state=NJ<br>year=%{x}<br>Agg_total_plant_count=%{y}", "legendgroup": "state=NJ", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "state=NJ", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [1219, 1272, 1392, 1848, 2086, 2585, 2772, 2962, 3579, 3822, 3940, 4400, 895, 518], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "state=AZ<br>year=%{x}<br>Agg_total_plant_count=%{y}", "legendgroup": "state=AZ", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "lines", "name": "state=AZ", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [862, 850, 912, 1087, 1154, 1423, 1513, 1555, 1624, 1768, 1872, 1909, 877, 512], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "state=NE<br>year=%{x}<br>Agg_total_plant_count=%{y}", "legendgroup": "state=NE", "line": {"color": "#FF6692", "dash": "solid"}, "mode": "lines", "name": "state=NE", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [1512, 1522, 1561, 1607, 1610, 1647, 1679, 1732, 1771, 1812, 1911, 1954, 359, 210], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "state=ND<br>year=%{x}<br>Agg_total_plant_count=%{y}", "legendgroup": "state=ND", "line": {"color": "#B6E880", "dash": "solid"}, "mode": "lines", "name": "state=ND", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [434, 498, 555, 581, 595, 654, 689, 737, 791, 850, 887, 891, 456, 266], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "state=MT< ...

# %%
px.line(df_pp.sort_values("year",ascending=True),x="year",y="Agg_total_plant_MWh",color="state",title="Aggregate Plant MWh Net Generation by State")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="dce36e8a-4ded-40b1-88b9-a02904d00e22" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("dce36e8a-4ded-40b1-88b9-a02904d00e22")) {
#                     Plotly.newPlot(
#                         'dce36e8a-4ded-40b1-88b9-a02904d00e22',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "state=AK<br>year=%{x}<br>Agg_total_plant_MWh=%{y}", "legendgroup": "state=AK", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "state=AK", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [6761250.704000001, 6695647.974000002, 6740874.002, 6849891.511999997, 6925729.124000002, 6490586.221, 6038796.715999997, 6265519.244000001, 6334531.727000001, 6496088.153999999, 6241510.388999998, 6063799.517999999, 1131604.98, 596514.2999999999], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "state=ME<br>year=%{x}<br>Agg_total_plant_MWh=%{y}", "legendgroup": "state=ME", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "state=ME", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [16088165.541, 15527834.452000005, 16141037.119000005, 15109213.894999998, 14498676.363000005, 13665064.258999998, 12945139.174, 11223592.199999996, 11018807.906, 10785808.322000002, 10826921.212, 10426159.14, 3885003.601, 2544338.4990000003], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "state=SC<br>year=%{x}<br>Agg_total_plant_MWh=%{y}", "legendgroup": "state=SC", "line": {"color": "#00cc96", "dash": "solid"}, "mode": "lines", "name": "state=SC", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [97918469.766, 98695945.406, 102263085.719, 101075511.174, 95054642.65, 94457125.96700001, 97158690.927, 96445390.818, 96985976.55700001, 93067190.065, 99322796.57100001, 99961243.385, 92569434.26600002, 55751320.673999995], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "state=TN<br>year=%{x}<br>Agg_total_plant_MWh=%{y}", "legendgroup": "state=TN", "line": {"color": "#ab63fa", "dash": "solid"}, "mode": "lines", "name": "state=TN", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [90645616.73300004, 79674619.71099998, 82290006.17900002, 81064402.197, 77687017.57100002, 79618657.43200001, 79471825.47599998, 75212443.14300002, 79340633.30900002, 77889347.00099999, 81537738.189, 81828023.76699999, 65103673.95700001, 40989999.046], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "state=OH<br>year=%{x}<br>Agg_total_plant_MWh=%{y}", "legendgroup": "state=OH", "line": {"color": "#FFA15A", "dash": "solid"}, "mode": "lines", "name": "state=OH", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [120974959.035, 106615496.58600004, 115306822.89, 110038371.14799996, 112014233.66399994, 117420716.559, 116397811.58599997, 106662564.445, 104135680.043, 108447405.91700001, 122492214.30899996, 119249554.96, 115041149.11, 65766855.957], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "state=NV<br>year=%{x}<br>Agg_total_plant_MWh=%{y}", "legendgroup": "state=NV", "line": {"color": "#19d3f3", "dash": "solid"}, "mode": "lines", "name": "state=NV", "showlegend": true, "type": "scatter", "x": [2008.0, 2009.0, 2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0, 2018.0, 2019.0, 2020.0, 2021.0], "xaxis": "x", "y": [31032652.562000006, 34189384.77, 32023859.69, 29390294.15, 33305802.86000001, 34665589.96, 33389455.000000004, 38170571.576, 38901397.0, 37937575.35, 39607668.69000001, 39857719.81, 36061980.18, 21203790.0], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "state=WV<br>year=%{x}<br>Agg_total_plant_MWh=%{y}", "legendgrou ...

# %%
df_pp
