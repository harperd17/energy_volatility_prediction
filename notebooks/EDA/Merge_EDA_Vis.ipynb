# %%
try:
    from google.colab import drive

    drive.mount('./drive/')

    # %cd drive/Shareddrives/Data606_Energy

except:
    print("No Colab Environment")
# Out:
# Mounted at ./drive/
# /content/drive/Shareddrives/Data606_Energy

# %%
import sys
import pandas as pd
import numpy as np
import glob
from tqdm.autonotebook import tqdm
import plotly.express as px
import plotly.figure_factory as ff
sys.path.append("helpers/")

from energygrid import EGRID

from helper_functions import write_csv,combine_like_files
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   """

# %%
energy_grid = EGRID()
energy_grid.get_states()
energy_grid.get_plant_fuel_types()

# %%
df = pd.read_csv("data/merge_ready/merged_data.csv")

# %%
df
# Out:
#      Year  ... RES_percapita_mean_kWh_statepop
# 0    2008  ...                           0.337
# 1    2008  ...                           0.359
# 2    2008  ...                           0.377
# 3    2008  ...                           0.436
# 4    2008  ...                           0.341
# ..    ...  ...                             ...
# 645  2020  ...                           0.405
# 646  2020  ...                           0.432
# 647  2020  ...                           0.339
# 648  2020  ...                           0.339
# 649  2020  ...                           0.187
#
# [650 rows x 123 columns]

# %%
column_counts = [{"Anchor":len(["Year","State"]),
                "Months Above Avg Price futures":len([col for col in df.columns if col.endswith("F")]),
                 "Weather":len([col for col in df.columns if col.endswith("Months")]),
                  "kWh Percapita Mean Electricity Usage":len([col for col in df.columns if "percapita" in col]),
                 "MWh Net Generation_fuel types":len([col for col in df.columns if col.startswith("R")]),
                 "Agg MWh_NetGeneration fuel types":len([col for col in df.columns if col.startswith("Agg")]),
                 "Target":len([col for col in df.columns if "COV" in col]),
                 }]


{'BZ=F':'Brent Crude Oil','NG=F':'Natural Gas','CL=F':'Light Sweet Crude Oil','HO=F':'Heating Oil'}
# Anchor  - Year, State
# Fuel Type (Net Generation) - 
# Electricity Usage - 
# Weather - 
# 

examples = ["State and Year","NG=F - Volume and Movement","Hot Summer Months"
            ,"COM_statepop and _electricacc"
            ,"R_Coal_MWh and _count","Agg_total_plant_MWh",
            "target_COV",]


df_vis = (pd.DataFrame(column_counts).T.reset_index()
.rename(columns={'index':"features",0:"count"})
)

df_vis["examples"] = examples



px.bar(df_vis,x="features",y="count",title=("Feature Counts"),text="examples")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="43088376-f3ed-41ff-9018-cb12533d4829" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("43088376-f3ed-41ff-9018-cb12533d4829")) {
#                     Plotly.newPlot(
#                         '43088376-f3ed-41ff-9018-cb12533d4829',
# ...

# %%
df_vis.sort_values("features",ascending=False)
# Out:
#                                       features  ...                       examples
# 1                            weather_data_cols  ...              Hot Summer Months
# 5                                  target_cols  ...                     target_COV
# 2    kWh_percapita_mean_electricity_usage_cols  ...  COM_statepop and _electricacc
# 6                                       anchor  ...                 State and Year
# 4                          agg_fuel_types_cols  ...            Agg_total_plant_MWh
# 0  Months_Above_Average_Price_future_data_cols  ...       Volume Brent Crude Oil=F
# 3                          MWh_fuel_types_cols  ...          R_Coal_MWh and _count
#
# [7 rows x 3 columns]
